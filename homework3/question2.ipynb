# %%
import pandas as pd
import plotly.express as px


muscle_df = pd.read_excel('Muscle_Data.xlsx', 'Force Vs Length')

# %%
muscle_df
# Out:
#     Voltage (V)  Length (mm)  Active Force (g)  Passive Force (g)  \
# 0           8.5           50              0.11               0.00
# 1           8.5           55              0.73               0.00
# 2           8.5           60              1.21               0.00
# 3           8.5           65              1.55               0.00
# 4           8.5           70              1.75               0.00
# 5           8.5           75              1.82               0.00
# 6           8.5           80              1.75               0.02
# 7           8.5           85              1.55               0.08
# 8           8.5           90              1.21               0.25
# 9           8.5           95              0.73               0.86
# 10          8.5          100              0.11               1.75
#
#     Total Force (g)
# 0              0.11
# 1              0.73
# 2              1.21
# 3              1.55
# 4              1.75
# 5              1.82
# 6              1.77
# ...

# %%
fig = px.line(muscle_df, x='Length (mm)', y=['Active Force (g)', 'Passive Force (g)', 'Total Force (g)'])
fig.update_layout(yaxis_title='Force (g)', legend_title='Force')
fig.update_layout(
    title = {
        'text': 'Force as a Function of Length',
        'x': 0.5,
        'font_size': 40
    }
)
fig.update_xaxes(title_font=dict(size=30), tickfont=dict(size=20))
fig.update_yaxes(title_font=dict(size=30), tickfont=dict(size=20))
fig.update_legend(title_font=dict(size=40))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20830/1639234395.py in <module>
#      10 fig.update_xaxes(title_font=dict(size=30), tickfont=dict(size=20))
#      11 fig.update_yaxes(title_font=dict(size=30), tickfont=dict(size=20))
# ---> 12 fig.update_legend(title_font=dict(size=40))
#      13 fig.show()
#
# AttributeError: 'Figure' object has no attribute 'update_legend'
